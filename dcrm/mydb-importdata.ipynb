# %%
#### Steps 
# import the csv file into a pandas df
# clean the table name and remove all extra symbols, spaces, capital letters
# write the create table SQL statement
# import the data into the db

# %%
# import libraries 
# conda install psycopg2
# pip install psycopg2

import os
import numpy as np
import pandas as pd
import psycopg2

# %%
df1 = pd.read_csv('./../mockdata/MOCK_DATA_1.csv')
df2 = pd.read_csv('./../mockdata/MOCK_DATA_2.csv')
df3 = pd.read_csv('./../mockdata/MOCK_DATA_3.csv')

df = pd.concat([df1,df2,df3], ignore_index=True)
df
# Out:
#         id  created_at  first_name    last_name  \
# 0        1  11/12/2022    Coleborn    Kennifick
# 1        2   1/12/2023      Hixson     Ranyelld
# 2        3    5/1/2023     Eilhart  Pollastrino
# 3        4   3/27/2023    Rajchert       Botten
# 4        5  10/17/2022     Incogna       Pappin
# ...    ...         ...         ...          ...
# 2995   996   2/10/2023      Gresty      Soulsby
# 2996   997   8/25/2022    Wilstead      Sambals
# 2997   998   9/22/2022      Sivill      Chelley
# 2998   999   7/23/2022  Beverstock      Gallety
# 2999  1000  10/17/2022       Blade       Mersey
#
#                       email_address         phone                  address  \
# 0            bkennifick0@jalbum.net  969-609-6213      9 Little Fleur Pass
# 1          dranyelld1@pinterest.com  188-924-1780          90 Eastwood Way
# 2            rpollastrino2@wisc.edu  200-966-3694        7375 Corben Plaza
# 3          abotten3@statcounter.com  373-234-1049  5593 Lotheville Parkway
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             3000 non-null   int64
#  1   created_at     3000 non-null   object
#  2   first_name     3000 non-null   object
#  3   last_name      3000 non-null   object
#  4   email_address  3000 non-null   object
#  5   phone          3000 non-null   object
#  6   address        3000 non-null   object
#  7   city           3000 non-null   object
#  8   state          506 non-null    object
#  9   zipcode        1439 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 234.5+ KB
